# %%
a=list([58, 72, 74, 92, 84, 40, 74, 81, 76, 83])
np.(a)
# Out:
# [58, 72, 74, 92, 84, 40, 74, 81, 76, 83]

# %%
import seaborn as sb
print(sb.get_dataset_names())
# Out:
# D:\Programdata\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file D:\Programdata\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
import tensorflow as tf;
print(tf.__version__)
# Out:
# 2.3.1

# %%
from sklearn import datasets as d
print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-899ad4754271> in <module>
#       1 from sklearn import datasets as d
# ----> 2 print(d.load_datasets_names())
#
# AttributeError: module 'sklearn.datasets' has no attribute 'load_datasets_names'

# %%
sklearn.datasets.get_data_home
# Out:
# <function sklearn.datasets._base.get_data_home(data_home=None)>

# %%
from sklearn import datasets
dir(datasets)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_base',
#  '_california_housing',
#  '_covtype',
#  '_kddcup99',
#  '_lfw',
#  '_olivetti_faces',
#  '_openml',
#  '_rcv1',
#  '_samples_generator',
#  '_species_distributions',
#  '_svmlight_format_fast',
#  '_svmlight_format_io',
#  '_twenty_newsgroups',
#  'clear_data_home',
#  'dump_svmlight_file',
#  'fetch_20newsgroups',
#  'fetch_20newsgroups_vectorized',
#  'fetch_california_housing',
#  'fetch_covtype',
#  'fetch_kddcup99',
#  'fetch_lfw_pairs',
#  'fetch_lfw_people',
#  'fetch_olivetti_faces',
#  'fetch_openml',
#  'fetch_rcv1',
#  'fetch_species_distributions',
#  'get_data_home',
#  'load_boston',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_sample_image',
#  'load_sample_images',
#  'load_svmlight_file',
#  'load_svmlight_files',
# ...

# %%
#date used as index
df=pd.DataFrame(randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['values'])
df
# Out:
#               values
# 2019-06-07  1.556305
# 2019-06-08  0.949395
# 2019-06-09  0.677296
# 2019-06-10  0.223882
# 2019-06-11  0.803472
# ...              ...
# 2022-02-26 -0.976828
# 2022-02-27  0.624647
# 2022-02-28 -1.191678
# 2022-03-01 -0.230352
# 2022-03-02  0.280604
#
# [1000 rows x 1 columns]

# %%
india=pd.read_csv('Indian_cities.csv')
plot=india.plot(kind='line',figsize=(15,15))
plt.show()

# %%
#line graph
plot=india.plot(kind='line',figsize=(15,15))
plot.set_xlabel('xaxis')
plot.set_ylabel('yaxis')
plt.show()

# %%
#to get desired columns in ryt format
india.columns
dell=india.drop(['name_of_city', 'state_code', 'state_name', 'dist_code'],axis=1,inplace=True)

# %%
india['lat']=india['location'].apply(lambda x: x.split(',')[1])

# %%
india['long']=india['location'].apply(lambda x: x.split(',')[0])

# %%
india.drop('location',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-d212af6d1b6b> in <module>
# ----> 1 india.drop('location',inplace=True)
#
# D:\Programdata\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# D:\Programdata\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# D:\Programdata\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
india.drop('location',axis=1,inplace=True)

# %%
india
# Out:
#      population_total  population_male  population_female  \
# 0              145238            76840              68398
# 1              112293            58256              54037
# 2              117388            59232              58156
# 3              173988            91495              82493
# 4              166537            82743              83794
# ..                ...              ...                ...
# 488            227533           111596             115937
# 489            620116           310400             309716
# 490            105543            53241              52302
# 491            216628           115404             101224
# 492            116714            58717              57997
#
#      0-6_population_total  0-6_population_male  0-6_population_female  \
# 0                   15870                 8587                   7283
# 1                   11810                 6186                   5624
# ...

# %%
#to convert the datatype of all the fields to float..to perform plot on entire dataset
india=india.astype('float')

# %%
#bar graph
india.iloc[0].plot.bar()

# %%
india=india.set_index('sex_ratio')

# %%
a=pd.DataFrame(india[['population_total']].diff())
a.dtypes
# Out:
# population_total    float64
# dtype: object

# %%
a.reset_index
# Out:
# <bound method DataFrame.reset_index of            population_total
# sex_ratio
# 890                     NaN
# 928                -32945.0
# 982                  5095.0
# 902                 56600.0
# 1013                -7451.0
# ...                     ...
# 1039             -1502787.0
# 998                392583.0
# 982               -514573.0
# 877                111085.0
# 988                -99914.0
#
# [493 rows x 1 columns]>

# %%
a.index
# Out:
# Int64Index([ 890,  928,  982,  902, 1013, 1002,  853,  897,  952, 1029,
#             ...
#             1032,  966,  915,  997,  977, 1039,  998,  982,  877,  988],
#            dtype='int64', name='sex_ratio', length=493)

# %%
a.index.values
# Out:
# array([ 890,  928,  982,  902, 1013, 1002,  853,  897,  952, 1029,  946,
#         939,  958,  997, 1076,  884,  858,  889,  895,  922,  910,  982,
#         920, 1031,  957,  921,  879,  918,  928,  995,  937,  874,  922,
#         981,  904,  919,  969,  912,  914,  885,  972,  858,  945,  890,
#         936,  960,  872,  863,  930,  998,  878,  951,  929,  954,  926,
#         935,  972,  884,  959,  881,  931,  869,  943,  948,  974,  907,
#         897,  883,  946,  875,  982,  988,  914,  888,  953,  949, 1010,
#         901,  878,  855,  880,  942,  878,  919,  942,  915, 1031,  872,
#         755,  700,  876,  911,  882,  889,  942,  933,  937,  960,  916,
#         976,  900,  945,  881,  962,  922,  917,  907,  906,  929,  872,
#         948,  896,  872,  981,  897,  829,  944,  897,  888,  986,  893,
#         963, 1013, 1023,  990,  933, 1008,  940,  999, 1025,  997,  951,
#         903,  919,  898, 1003,  898,  973,  893,  906,  896,  875,  719,
# ...

# %%
#histogaram and its attributes
india['total_graduates'].diff().plot(kind='hist',bins=10,orientation='horizontal',alpha=0.9,color='r',stacked=False,figsize=(15,15),edgecolor='r')
plt.show()

# %%
india['population_total'].plot(kind='hist',figsize=(15,15),edgecolor='r',color='b',bins=20,stacked=True)

# %%
#scatter plot
india.plot.scatter(x='name_of_city',y='literates_total',c='state_code',label='lets try')

# %%
#two graph in single view
ax=india.plot.scatter(x='name_of_city',y='literates_total',c='b',label='graph 1')
india.plot.scatter(x='name_of_city',y='population_total',label='graph 2',ax=ax,color='r',s=300)

# %%
#hexbin
india.plot.hexbin(x='population_total',y='literates_total',label='graph 2',color='r',gridsize=5)

# %%
india=india.drop(['name_of_city', 'state_code', 'state_name','location'],axis=1)
india.astype('float')
# Out:
#      dist_code  population_total  population_male  population_female  \
# 0          9.0          145238.0          76840.0            68398.0
# 1          7.0          112293.0          58256.0            54037.0
# 2          1.0          117388.0          59232.0            58156.0
# 3         24.0          173988.0          91495.0            82493.0
# 4         21.0          166537.0          82743.0            83794.0
# ..         ...               ...              ...                ...
# 488       12.0          227533.0         111596.0           115937.0
# 489        9.0          620116.0         310400.0           309716.0
# 490        8.0          105543.0          53241.0            52302.0
# 491        3.0          216628.0         115404.0           101224.0
# 492       14.0          116714.0          58717.0            57997.0
#
#      0-6_population_total  0-6_population_male  0-6_population_female  \
# ...

# %%
#pie plot
a=india[['dist_code','population_total','population_male']]
indd=a.head(5)
indd.plot.pie(subplots=True,figsize=(15,15),autopct='%.2f')
indd
# Out:
#    dist_code  population_total  population_male
# 0          9            145238            76840
# 1          7            112293            58256
# 2          1            117388            59232
# 3         24            173988            91495
# 4         21            166537            82743

# %%
#scatter-matrix
from pandas.plotting import scatter_matrix
aa=india.head()
scatter_matrix(a,figsize=(15,15),color='r',diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021D46AA5C48>,
# ...
#       dtype=object)

# %%
#using style 
aa.plot(style='r--',label='series',layout=(2,3),sharex=True,legend=True)
plt.tight_layout()
